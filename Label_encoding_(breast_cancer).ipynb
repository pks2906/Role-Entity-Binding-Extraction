# %% [markdown]
# <a href="https://colab.research.google.com/github/pks2906/Breast-cancer-prediction-using-machine-learning/blob/main/Label_encoding_(breast_cancer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Label encoding
#
# Converting the label into numeric form

# %%
# importing the dependies
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Label encoding of breast cancer data set

# %%
#loading the data from csv file to pandas dataframe
cancer_data = pd.read_csv('/content/breast_cancer_data.csv')

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# finding the count of different labels
cancer_data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#load the label encoder function
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(cancer_data.diagnosis)

# %%
# appending the label to the dataframe
cancer_data['target'] = labels

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# 0.----> Benign
#
#
#
#
# 1.----> Malignant

# %%
cancer_data['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64
